# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # this is a notebook for mmb coding workshop

# %% [markdown]
# I will be demonstrating how to add two numbers

# %%
2+3
# Out:
# 5

# %% [markdown]
# Now I will output hello world

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Lets discuss variables

# %%
a = 10
b = 1.1
c = "word"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
c = "123"

# %%
type(c)
# Out:
# str

# %%
array1 = [1,2,3,4,5]

# %%
array2 = [[10000,221,34,476], [6,323,878,1]]

# %%
plt.imshow(array2, cmap = 'Blues')
plt.colorbar()

# %%
array2 = [[10000,221,34,476], [6,323,878,1], [5000,221,1345,476], [6,3321,5563,1]]

# %%
plt.imshow(array2)
